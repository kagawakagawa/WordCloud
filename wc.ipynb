# %%
from wordcloud import WordCloud
import os
# テキストファイル読み込み
f = open(os.path.sep.join(['english_text.txt']), encoding='utf-8')
raw = f.read()
f.close()
print(raw)

wc = WordCloud().generate(raw)
wc.to_file("wc-1.png")
# Out:
# In this paper, we consider a nonparametric adaptive
# software rejuvenation schedule under a random censored data.
# For u failure time data and v random censored data, we
# formulate upper and lower bounds of the predictive system
# availability based on a nonparametric predictive inference (NPI).
# Then, we derive adaptive rejuvenation policies which maximizes
# the upper or lower bound. In simulation experiments, we show
# that estimates of the software rejuvenation schedule are updated
# by acquisition of new failure data, and converge to the theoretical
# optimal solution.

# %%
wc = WordCloud().generate(raw)
wc.to_file("wc-1.png")

# %%
# !apt install aptitude
# !aptitude install mecab libmecab-dev mecab-ipadic-utf8 git make curl xz-utils file -y
# !pip install mecab-python3==0.7
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   aptitude-common libcgi-fast-perl libcgi-pm-perl libclass-accessor-perl
#   libcwidget4 libencode-locale-perl libfcgi-perl libhtml-parser-perl
#   libhtml-tagset-perl libhttp-date-perl libhttp-message-perl libio-html-perl
#   libio-string-perl liblocale-gettext-perl liblwp-mediatypes-perl
#   libparse-debianchangelog-perl libsigc++-2.0-0v5 libsub-name-perl liburi-perl
#   libxapian30
# Suggested packages:
#   aptitude-doc-en | aptitude-doc apt-xapian-index debtags tasksel
#   libcwidget-dev libdata-dump-perl libhtml-template-perl libxml-simple-perl
#   libwww-perl xapian-tools
# The following NEW packages will be installed:
#   aptitude aptitude-common libcgi-fast-perl libcgi-pm-perl
#   libclass-accessor-perl libcwidget4 libencode-locale-perl libfcgi-perl
#   libhtml-parser-perl libhtml-tagset-perl libhttp-date-perl
#   libhttp-message-perl libio-html-perl libio-string-perl
#   liblocale-gettext-perl liblwp-mediatypes-perl libparse-debianchangelog-perl
#   libsigc++-2.0-0v5 libsub-name-perl liburi-perl libxapian30
# 0 upgraded, 21 newly installed, 0 to remove and 13 not upgraded.
# Need to get 4,662 kB of archives.
# After this operation, 20.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 liblocale-gettext-perl amd64 1.07-4 [17.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 aptitude-common all 0.8.12-1ubuntu4 [1,711 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 libsigc++-2.0-0v5 amd64 2.10.2-1build1 [11.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 libcwidget4 amd64 0.5.18-5build1 [306 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 libxapian30 amd64 1.4.14-2 [661 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/universe amd64 aptitude amd64 0.8.12-1ubuntu4 [1,323 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 libhtml-tagset-perl all 3.20-4 [12.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 liburi-perl all 1.76-2 [77.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 libhtml-parser-perl amd64 3.72-5 [86.3 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/main amd64 libcgi-pm-perl all 4.46-1 [186 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 libfcgi-perl amd64 0.79-1 [33.1 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 libcgi-fast-perl all 1:2.15-1 [10.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 libsub-name-perl amd64 0.26-1 [11.5 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/universe amd64 libclass-accessor-perl all 0.51-1 [21.2 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 libencode-locale-perl all 1.05-1 [12.3 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 libhttp-date-perl all 6.05-1 [9,920 B]
# Get:17 http://archive.ubuntu.com/ubuntu focal/main amd64 libio-html-perl all 1.001-1 [14.9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal/main amd64 liblwp-mediatypes-perl all 6.04-1 [19.5 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal/main amd64 libhttp-message-perl all 6.22-1 [76.1 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 libio-string-perl all 1.08-3 [11.1 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal/universe amd64 libparse-debianchangelog-perl all 1.2.0-13 [49.7 kB]
# Fetched 4,662 kB in 2s (2,616 kB/s)
# Selecting previously unselected package liblocale-gettext-perl.
# (Reading database ... 123069 files and directories currently installed.)
# Preparing to unpack .../00-liblocale-gettext-perl_1.07-4_amd64.deb ...
# Unpacking liblocale-gettext-perl (1.07-4) ...
# Selecting previously unselected package aptitude-common.
# Preparing to unpack .../01-aptitude-common_0.8.12-1ubuntu4_all.deb ...
# Unpacking aptitude-common (0.8.12-1ubuntu4) ...
# Selecting previously unselected package libsigc++-2.0-0v5:amd64.
# Preparing to unpack .../02-libsigc++-2.0-0v5_2.10.2-1build1_amd64.deb ...
# Unpacking libsigc++-2.0-0v5:amd64 (2.10.2-1build1) ...
# Selecting previously unselected package libcwidget4:amd64.
# Preparing to unpack .../03-libcwidget4_0.5.18-5build1_amd64.deb ...
# Unpacking libcwidget4:amd64 (0.5.18-5build1) ...
# Selecting previously unselected package libxapian30:amd64.
# Preparing to unpack .../04-libxapian30_1.4.14-2_amd64.deb ...
# Unpacking libxapian30:amd64 (1.4.14-2) ...
# Selecting previously unselected package aptitude.
# Preparing to unpack .../05-aptitude_0.8.12-1ubuntu4_amd64.deb ...
# Unpacking aptitude (0.8.12-1ubuntu4) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../06-libhtml-tagset-perl_3.20-4_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-4) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../07-liburi-perl_1.76-2_all.deb ...
# Unpacking liburi-perl (1.76-2) ...
# Selecting previously unselected package libhtml-parser-perl.
# Preparing to unpack .../08-libhtml-parser-perl_3.72-5_amd64.deb ...
# Unpacking libhtml-parser-perl (3.72-5) ...
# Selecting previously unselected package libcgi-pm-perl.
# Preparing to unpack .../09-libcgi-pm-perl_4.46-1_all.deb ...
# Unpacking libcgi-pm-perl (4.46-1) ...
# Selecting previously unselected package libfcgi-perl.
# Preparing to unpack .../10-libfcgi-perl_0.79-1_amd64.deb ...
# Unpacking libfcgi-perl (0.79-1) ...
# Selecting previously unselected package libcgi-fast-perl.
# Preparing to unpack .../11-libcgi-fast-perl_1%3a2.15-1_all.deb ...
# Unpacking libcgi-fast-perl (1:2.15-1) ...
# Selecting previously unselected package libsub-name-perl.
# Preparing to unpack .../12-libsub-name-perl_0.26-1_amd64.deb ...
# Unpacking libsub-name-perl (0.26-1) ...
# Selecting previously unselected package libclass-accessor-perl.
# Preparing to unpack .../13-libclass-accessor-perl_0.51-1_all.deb ...
# Unpacking libclass-accessor-perl (0.51-1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../14-libencode-locale-perl_1.05-1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../15-libhttp-date-perl_6.05-1_all.deb ...
# Unpacking libhttp-date-perl (6.05-1) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../16-libio-html-perl_1.001-1_all.deb ...
# Unpacking libio-html-perl (1.001-1) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../17-liblwp-mediatypes-perl_6.04-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.04-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../18-libhttp-message-perl_6.22-1_all.deb ...
# Unpacking libhttp-message-perl (6.22-1) ...
# Selecting previously unselected package libio-string-perl.
# Preparing to unpack .../19-libio-string-perl_1.08-3_all.deb ...
# Unpacking libio-string-perl (1.08-3) ...
# Selecting previously unselected package libparse-debianchangelog-perl.
# Preparing to unpack .../20-libparse-debianchangelog-perl_1.2.0-13_all.deb ...
# Unpacking libparse-debianchangelog-perl (1.2.0-13) ...
# Setting up libxapian30:amd64 (1.4.14-2) ...
# Setting up libhttp-date-perl (6.05-1) ...
# Setting up libhtml-tagset-perl (3.20-4) ...
# Setting up liblwp-mediatypes-perl (6.04-1) ...
# Setting up libencode-locale-perl (1.05-1) ...
# Setting up libio-string-perl (1.08-3) ...
# Setting up libsigc++-2.0-0v5:amd64 (2.10.2-1build1) ...
# Setting up aptitude-common (0.8.12-1ubuntu4) ...
# Setting up libio-html-perl (1.001-1) ...
# Setting up libsub-name-perl (0.26-1) ...
# Setting up libfcgi-perl (0.79-1) ...
# Setting up libclass-accessor-perl (0.51-1) ...
# Setting up liburi-perl (1.76-2) ...
# Setting up liblocale-gettext-perl (1.07-4) ...
# Setting up libhttp-message-perl (6.22-1) ...
# Setting up libcwidget4:amd64 (0.5.18-5build1) ...
# Setting up aptitude (0.8.12-1ubuntu4) ...
# update-alternatives: using /usr/bin/aptitude-curses to provide /usr/bin/aptitude (aptitude) in auto mode
# Setting up libhtml-parser-perl (3.72-5) ...
# Setting up libcgi-pm-perl (4.46-1) ...
# Setting up libparse-debianchangelog-perl (1.2.0-13) ...
# Setting up libcgi-fast-perl (1:2.15-1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# git is already installed at the requested version (1:2.25.1-1ubuntu3.11)
# make is already installed at the requested version (4.2.1-1.2)
# curl is already installed at the requested version (7.68.0-1ubuntu2.18)
# xz-utils is already installed at the requested version (5.2.4-1ubuntu1.1)
# file is already installed at the requested version (1:5.38-4)
# git is already installed at the requested version (1:2.25.1-1ubuntu3.11)
# make is already installed at the requested version (4.2.1-1.2)
# curl is already installed at the requested version (7.68.0-1ubuntu2.18)
# xz-utils is already installed at the requested version (5.2.4-1ubuntu1.1)
# file is already installed at the requested version (1:5.38-4)
# The following NEW packages will be installed:
#   libmecab-dev libmecab2{a} mecab mecab-ipadic{a} mecab-ipadic-utf8 mecab-jumandic{a} mecab-jumandic-utf8{a} mecab-utils{a}
# 0 packages upgraded, 8 newly installed, 0 to remove and 13 not upgraded.
# Need to get 23.5 MB of archives. After unpacking 276 MB will be used.
# Get: 1 http://archive.ubuntu.com/ubuntu focal/main amd64 libmecab2 amd64 0.996-10build1 [233 kB]
# Get: 2 http://archive.ubuntu.com/ubuntu focal/main amd64 libmecab-dev amd64 0.996-10build1 [285 kB]
# Get: 3 http://archive.ubuntu.com/ubuntu focal/main amd64 mecab-utils amd64 0.996-10build1 [4,912 B]
# Get: 4 http://archive.ubuntu.com/ubuntu focal/universe amd64 mecab-jumandic-utf8 all 7.0-20130310-7 [16.2 MB]
# Get: 5 http://archive.ubuntu.com/ubuntu focal/universe amd64 mecab-jumandic all 7.0-20130310-7 [2,204 B]
# Get: 6 http://archive.ubuntu.com/ubuntu focal/main amd64 mecab-ipadic all 2.7.0-20070801+main-2.1 [6,714 kB]
# Get: 7 http://archive.ubuntu.com/ubuntu focal/universe amd64 mecab amd64 0.996-10build1 [132 kB]
# Get: 8 http://archive.ubuntu.com/ubuntu focal/main amd64 mecab-ipadic-utf8 all 2.7.0-20070801+main-2.1 [4,380 B]
# Fetched 23.5 MB in 2s (13.8 MB/s)
# Selecting previously unselected package libmecab2:amd64.
# (Reading database ... 123570 files and directories currently installed.)
# Preparing to unpack .../0-libmecab2_0.996-10build1_amd64.deb ...
# Unpacking libmecab2:amd64 (0.996-10build1) ...
# Selecting previously unselected package libmecab-dev.
# Preparing to unpack .../1-libmecab-dev_0.996-10build1_amd64.deb ...
# Unpacking libmecab-dev (0.996-10build1) ...
# Selecting previously unselected package mecab-utils.
# Preparing to unpack .../2-mecab-utils_0.996-10build1_amd64.deb ...
# Unpacking mecab-utils (0.996-10build1) ...
# Selecting previously unselected package mecab-jumandic-utf8.
# Preparing to unpack .../3-mecab-jumandic-utf8_7.0-20130310-7_all.deb ...
# Unpacking mecab-jumandic-utf8 (7.0-20130310-7) ...
# Selecting previously unselected package mecab-jumandic.
# Preparing to unpack .../4-mecab-jumandic_7.0-20130310-7_all.deb ...
# Unpacking mecab-jumandic (7.0-20130310-7) ...
# Selecting previously unselected package mecab-ipadic.
# Preparing to unpack .../5-mecab-ipadic_2.7.0-20070801+main-2.1_all.deb ...
# Unpacking mecab-ipadic (2.7.0-20070801+main-2.1) ...
# Selecting previously unselected package mecab.
# Preparing to unpack .../6-mecab_0.996-10build1_amd64.deb ...
# Unpacking mecab (0.996-10build1) ...
# Selecting previously unselected package mecab-ipadic-utf8.
# Preparing to unpack .../7-mecab-ipadic-utf8_2.7.0-20070801+main-2.1_all.deb ...
# Unpacking mecab-ipadic-utf8 (2.7.0-20070801+main-2.1) ...
# Setting up libmecab2:amd64 (0.996-10build1) ...
# Setting up libmecab-dev (0.996-10build1) ...
# Setting up mecab-utils (0.996-10build1) ...
# Setting up mecab-ipadic (2.7.0-20070801+main-2.1) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27328
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Setting up mecab (0.996-10build1) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27328
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# Setting up mecab-jumandic-utf8 (7.0-20130310-7) ...
# Compiling Juman dictionary for Mecab.
# reading /usr/share/mecab/dic/juman/unk.def ... 37
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/juman/Auto.csv ... 18931
# reading /usr/share/mecab/dic/juman/Rengo.csv ... 1118
# reading /usr/share/mecab/dic/juman/Postp.csv ... 108
# reading /usr/share/mecab/dic/juman/Assert.csv ... 34
# reading /usr/share/mecab/dic/juman/ContentW.csv ... 551145
# reading /usr/share/mecab/dic/juman/Noun.keishiki.csv ... 8
# reading /usr/share/mecab/dic/juman/Emoticon.csv ... 972
# reading /usr/share/mecab/dic/juman/Noun.suusi.csv ... 49
# reading /usr/share/mecab/dic/juman/Wikipedia.csv ... 167709
# reading /usr/share/mecab/dic/juman/AuxV.csv ... 593
# reading /usr/share/mecab/dic/juman/Suffix.csv ... 2128
# reading /usr/share/mecab/dic/juman/Noun.koyuu.csv ... 7964
# reading /usr/share/mecab/dic/juman/Special.csv ... 158
# reading /usr/share/mecab/dic/juman/Demonstrative.csv ... 97
# reading /usr/share/mecab/dic/juman/Prefix.csv ... 90
# reading /usr/share/mecab/dic/juman/Noun.hukusi.csv ... 81
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/juman/matrix.def ... 1876x1876
# emitting matrix      : 100% |###########################################|
#
# done!
# Setting up mecab-ipadic-utf8 (2.7.0-20070801+main-2.1) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27328
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic-utf8 to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Setting up mecab-jumandic (7.0-20130310-7) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
#
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mecab-python3==0.7
#   Downloading mecab-python3-0.7.tar.gz (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mecab-python3
#   Building wheel for mecab-python3 (setup.py) ... done
#   Created wheel for mecab-python3: filename=mecab_python3-0.7-cp310-cp310-linux_x86_64.whl size=204654 sha256=3d9e0c21877022c6cf3a8d8f1de1e38a86b4509ddc9406ceefc37f20c049c3b2
#   Stored in directory: /root/.cache/pip/wheels/af/5c/2a/bb8c7ed306516444e25b06556edf0e8f0b82139b270eb4ce2d
# Successfully built mecab-python3
# Installing collected packages: mecab-python3
# Successfully installed mecab-python3-0.7

# %%
import MeCab as mc
import re

# %%
def strip_CRLF_from_Text(text):
    """テキストファイルの改行，タブを削除し，形態素解析を実行する．
    改行前後が日本語文字の場合は改行を削除する．
    それ以外はスペースに置換する．
    """
    # 改行前後の文字が日本語文字の場合は改行を削除する
    plaintext = re.sub('([ぁ-んー]+|[ァ-ンー]+|[\\u4e00-\\u9FFF]+|[ぁ-んァ-ンー\\u4e00-\\u9FFF]+)(\n)([ぁ-んー]+|[ァ-ンー]+|[\\u4e00-\\u9FFF]+|[ぁ-んァ-ンー\\u4e00-\\u9FFF]+)',
                       r'\1\3',
                       text)
    # 残った改行とタブ記号はスペースに置換する
    plaintext = plaintext.replace('\n', ' ').replace('\t', ' ')
    return plaintext

def mecab_wakati(text):
    """
    MeCabで分かち書き．
    ただし品詞は名詞だけに限定．
    """
    t = mc.Tagger()
    # t = mc.Tagger('-d /usr/local/lib/mecab/dic/mecab-ipadic-neologd/')

    node = t.parseToNode(text)
#     print(node)
    sent = ""
    while(node):
#         print(node.surface, node.feature)
        if node.surface != "":  # ヘッダとフッタを除外
            word_type = node.feature.split(",")[0]
            # 名詞だけをリストに追加する
            if word_type in ["名詞"]:
                 sent += node.surface + " "  # node.surface は「表層形」
            # 動詞（の原型），形容詞，副詞もリストに加えたい場合は次の２行を有効にする
            if word_type in [ "動詞", "形容詞","副詞"]:
                sent += node.feature.split(",")[6] + " " # node.feature.split(",")[6] は形態素解析結果の「原型」
        node = node.next
        if node is None:
            break
    return sent

# テキストファイル読み込み
f = open(os.path.sep.join(['es_text.txt']), encoding='utf-8')
raw = f.read()
f.close()
print(raw)
text = strip_CRLF_from_Text(raw)
print(text)
sent = mecab_wakati(text)
print(sent)
stop_words = ['ある','する','こと','とても','いる','できる','よう','思う','ため','なる','それ','私','自分','れる','られる','の','たち','考える']


# フォントの保存先を指定する（環境によって書き換えてください）
#font_path = "C:\\WINDOWS\\FONTS\\MEIRYO.TTC"    ## Windows 版はこちら
font_path = "/usr/share/fonts/truetype/fonts-japanese-gothic.ttf"
#wc = WordCloud(max_font_size=36, font_path=font_path).generate(sent)
wc = WordCloud(
    font_path=font_path,
    width=900, height=600,   # default width=400, height=200
    background_color="white",   # default=”black”
    stopwords=set(stop_words),
    max_words=500,   # default=200
    min_font_size=4,   #default=4
    collocations = False   #default = True
    ).generate(sent)
wc.to_file("wc-2.png")
# WordCloud画像を生成する
#wc = WordCloud(max_font_size=36, font_path=font_path).generate(sent)
#wc.to_file("wc-5.png")
# Out:
# Pythonを使って引き分けを狙うオセロAIを作成した。探索アルゴリズムであるモンテカルロ木探索を応用した。論文を読み分野の理解を深め、研究をおこなった。目標達成のために既存のアルゴリズムの評価方法や分岐に変更を加え続け、実験のたびにフィードバックを得て少しずつモデルの精度を上げていった。この研究を通して知識、技術を得て、一つのことを本気で続けるという継続することの大切さを知ることができた。私が大学で最も成果を残した経験は卒業研究および卒業論文執筆です。内容は拮抗した試合展開を行うオセロAIの開発です。モンテカルロ木探索という探索アルゴリズムを応用しました。背景はユーザーの実力に関係なく柔軟に対応できるAIがあれば、ゲームを楽しみつつ、レベルアップを期待できるシステムが開発できると考えたためです。多くの関連した論文を読み分野の理解を深め、研究を行いました。こだわった点は目標達成のために既存のアルゴリズムに変更を加え続け実験のたびにフィードバックを得て少しずつモデルの精度を上げていったことです。結果としては、一定のレベルのいくつかのAI相手には勝率が5分に近い値に収束することができました。またプレゼン時のスライドの見せ方もこだわりました。グラフやヒストグラムをどう使えばわかりやすいか、何度も発表練習を行い考えました。この結果、何を伝えたいのかを自分でしっかり考えることが必要だと理解できました。そして、この研究を通して知識、技術を得て、一つのことを本気で続けるという継続することの大切さを知ることができました。私が学生時代最も頑張ったことは塾講師のアルバイトで生徒たちの成績をあげるために試行錯誤したことである。当時、社員との会議で生徒の成績が上がらないという問題が出た。私はこの問題を解決するために、講師たちが提出する各生徒の電子日報に、内容に応じて報酬を与えるという制度を提案した。IT、ITやデータたちはフィードバックをより正確に行うようになり、の得意不得意、苦労した問題など細かく共有をし、とても指導がしやすくなった。やる気よりも、やる気を上げたことで問題が解決したのである。そして友人の状況まで人気が出ている。この業務でも問題を様々な角度から見ることで、解決の糸口を掴みたい。また長所は価値観を広げることに、重きを置いていることです。新たな発見や知識の収集に関心があり、他分野について精通している人間とも交流をとり、勉強面では少しでも気になったことは、すぐに調べています。しかし好奇心だけで即座に行動に移さず、慎重に物事を考えることも必要だと感じています。学生時代に力を注いだことは卒業研究です。得られた知識、技術のみならず、自分との戦いの中めげずに友人と支え合い最後までやりきることができたこの経験は、今後の社会生活でも活用できる、とても価値のあるものだと思っています。志望する理由は自分のスキルアップと、実際に責任を持って仕事を行うことで得られる自己成長のための経験が欲しいためです。私は学部時代に情報学を専攻しており、当時の授業の経験を活かし、ニューラルネットワークを用いた自己学習するマルバツゲームを作ったことがあります。この時に、自分が書いたプログラムで、機械が自ら学習を行い、ゲームとして動作した時に、強い達成感を覚えました。そのために、このインターンを通して、貴社の技術や社員の方々の考え方、そして仕事への向き合い方を最も近い距離で経験し、吸収することで自らの成長に繋げたいと考えております。志望する理由は自分のスキルアップと、実際に責任を持って仕事を行うことで得られる、自己成長のための経験が欲しいためです。私は高校時代所属していた水泳部で副部長を任されていた時に、今までよりも責任が増えた状況で自分は何をすべきなのかを先生と一緒に考え、実行したことで大きく成長ができました。具体的にはあいさつの徹底と、部活終わりの細かなフィードバックです。今思えば当たり前のことですが、当時はこのことに気づき、実行できた時にとても感動しました。このような物事の解決や最善の方法を考え、実行する経験は自らをとても成長させると思います。そのために、このインターンを通して、私は貴社の技術や社員の方々の考え方、そして仕事への向き合い方を最も近い距離で経験し、吸収することで仕事における自らの成長に繋げたいと考えております。私は近い将来、多くの人の生活を豊かにするサービスの開発に携わりたい。それが私の人生の充実に繋がると考えているからだ。私は学生の頃にニューラルネットワークを使い、手書き数字の分類や、マルバツゲームを作ったことがある。そして、自分の書いたプログラムが実際に動作した時に、とても感動し、自分の手で何かを作ることの楽しさを知った。また、3年間続けた塾講師のアルバイトでは、生徒の学力向上のために、毎回日報を書き、一人ひとりに適した指導方法を考えていた。これによりテストの点が上がった時は、生徒たち以上に喜んだ。誰かのために努力をし、それが実ったときの幸せは何にも変え難いものである。したがって、私はこの二つの経験から、誰かのためになるサービスを自らの手で作りたいと考えている。その経験は大きな自信や生きがいになるだろう。データはあるだけでなく使いこなせないと意味がないため、学んだことやこれから学ぶことを駆使して状況に応じたよりよいデータの使用方法を提案したいです。また、昔から想像力豊かで柔軟な発想が得意なため面白い新たなアイデアを出せると思います。周りを観察し状況をしっかり見極め、痒いところに手が届く人間になりたい。コミュニティケーション能力はもちろん、データの扱いにも秀でた存在になりたいと思っている。データはあるだけでなく使いこなせないと意味がないため、データサイエンティスト、学んだことやこれから学ぶことを駆使して状況に応じたよりよいデータの使用方法を提案したい。また、昔から想像力豊かで柔軟な発想が得意なため面白い新たなアイデアを出す自信がある。近い将来は多くの知識、技術をつけて人に頼られるエンジニアでいたい。また、今後働くにあたって自信となる経験が欲しいため、小さくても何かしらのプロジェクトを任され、それが成功するよう努力をする。データサイエンティスト。必要なことは挑戦できる機会から逃げないことである。人は嫌なことから簡単に逃げられるが、成長するためには未体験の領域にいくことも大切だろう。仮に失敗してもそれも良い経験となるからだ。そのような経験値がもっと得られれば、自信やスキルが身につき色々なことをクリアし、周りからの評価も上がると考えている。チーム、個人開発など当初はプログラミング未経験だったため、環境構築や基礎的な分析をおこなった。一年後にはチームで作品を開発しサークル内で発表した。私たちはニューラルネットワークを用いた丸バツゲームを作成した。AlphaZeroをもとにし、ランダム対戦したデータを学習させ良い手を打ち、さらにそのデータを使って学習させる、というシステムである。学習には三日間使い、人間と同等、全探索アルゴリズムとも五分五分といういい結果となった。長所は価値観を広げることに、重きを置いていることです。新たな発見や知識の収集に関心があり、他分野について精通している人間とも交流をとり、勉強面では少しでも気になったことは、すぐに調べています。しかし好奇心だけで即座に行動に移さず、慎重に物事を考えることも必要だと感じています。弱みは人前で自信を持って自分の意見を言うのに躊躇いがあることです。昔から流されやすい性格なため、思うことがあっても言わずにいることが多かったです。そんな自分を変えるため今では自分の頭で物事を考え積極的に意見を言うように努力しています。目標の立て方を大事にしている。行動する前に自分が興味を持っている分野に関連した論文を読み、何が行われていてその課題はどのような物なのか、そして自分はそれに対して何ができるかを明確にしてから目標を立てている。開発や研究でエラーが続いたり思うような結果が出ないような時に、ノートに手書きで問題点とその明確な解決方法を全て書くようにしていること。昔から考えていることをノートに書くと頭の整理ができて落ち着いて問題を対処できるため、今でもこの方法を使っている。必要なことは挑戦できる機会から逃げないことである。人は嫌なことから簡単に逃げられるが、成長するためには未体験の領域にいくことも大切だろう。仮に失敗してもそれも良い経験となるからだ。そのような経験値がもっと得られれば、自信やスキルが身につき色々なことをクリアし、周りからの評価も上がると考えている。私は強みは、問題解決能力である。私が塾講師のアルバイトをしていた頃、社員との会議で成績の上がらない問題が出た。そこで私は、講師たちが授業後に提出する電子日報に、内容に応じて報酬を与えるという制度を提案した。それにより講師たちはフィードバックをより正確に行うようになり、各生徒の得意不得意だけでなく、できなかったITコンサルやその間違い方まで細かく共有をし、とても指導がしやすくなった。生徒のやる気よりも、講師のやる気を上げた解決したのである。そして今では入塾困難な状況まで人気が出ている。この業務でも問題を様々な角度から見ることで、解決の糸口を掴みたい。私が貴社のインターンを志望する理由はコンサルタントという職業をもっと深く知りたいからです。昔から家族や友達、多くの人と助け合うことを大切にしていたため、自分の得意分野を使って人や企業の問題を解決し、支援をするコンサルタントにとても憧れがありました。3年間 ...
# Pythonを使って引き分けを狙うオセロAIを作成した。探索アルゴリズムであるモンテカルロ木探索を応用した。論文を読み分野の理解を深め、研究をおこなった。目標達成のために既存のアルゴリズムの評価方法や分岐に変更を加え続け、実験のたびにフィードバックを得て少しずつモデルの精度を上げていった。この研究を通して知識、技術を得て、一つのことを本気で続けるという継続することの大切さを知ることができた。私が大学で最も成果を残した経験は卒業研究および卒業論文執筆です。内容は拮抗した試合展開を行うオセロAIの開発です。モンテカルロ木探索という探索アルゴリズムを応用しました。背景はユーザーの実力に関係なく柔軟に対応できるAIがあれば、ゲームを楽しみつつ、レベルアップを期待できるシステムが開発できると考えたためです。多くの関連した論文を読み分野の理解を深め、研究を行いました。こだわった点は目標達成のために既存のアルゴリズムに変更を加え続け実験のたびにフィードバックを得て少しずつモデルの精度を上げていったことです。結果としては、一定のレベルのいくつかのAI相手には勝率が5分に近い値に収束することができました。またプレゼン時のスライドの見せ方もこだわりました。グラフやヒストグラムをどう使えばわかりやすいか、何度も発表練習を行い考えました。この結果、何を伝えたいのかを自分でしっかり考えることが必要だと理解できました。そして、この研究を通して知識、技術を得て、一つのことを本気で続けるという継続することの大切さを知ることができました。私が学生時代最も頑張ったことは塾講師のアルバイトで生徒たちの成績をあげるために試行錯誤したことである。当時、社員との会議で生徒の成績が上がらないという問題が出た。私はこの問題を解決するために、講師たちが提出する各生徒の電子日報に、内容に応じて報酬を与えるという制度を提案した。IT、ITやデータたちはフィードバックをより正確に行うようになり、の得意不得意、苦労した問題など細かく共有をし、とても指導がしやすくなった。やる気よりも、やる気を上げたことで問題が解決したのである。そして友人の状況まで人気が出ている。この業務でも問題を様々な角度から見ることで、解決の糸口を掴みたい。また長所は価値観を広げることに、重きを置いていることです。新たな発見や知識の収集に関心があり、他分野について精通している人間とも交流をとり、勉強面では少しでも気になったことは、すぐに調べています。しかし好奇心だけで即座に行動に移さず、慎重に物事を考えることも必要だと感じています。学生時代に力を注いだことは卒業研究です。得られた知識、技術のみならず、自分との戦いの中めげずに友人と支え合い最後までやりきることができたこの経験は、今後の社会生活でも活用できる、とても価値のあるものだと思っています。志望する理由は自分のスキルアップと、実際に責任を持って仕事を行うことで得られる自己成長のための経験が欲しいためです。私は学部時代に情報学を専攻しており、当時の授業の経験を活かし、ニューラルネットワークを用いた自己学習するマルバツゲームを作ったことがあります。この時に、自分が書いたプログラムで、機械が自ら学習を行い、ゲームとして動作した時に、強い達成感を覚えました。そのために、このインターンを通して、貴社の技術や社員の方々の考え方、そして仕事への向き合い方を最も近い距離で経験し、吸収することで自らの成長に繋げたいと考えております。志望する理由は自分のスキルアップと、実際に責任を持って仕事を行うことで得られる、自己成長のための経験が欲しいためです。私は高校時代所属していた水泳部で副部長を任されていた時に、今までよりも責任が増えた状況で自分は何をすべきなのかを先生と一緒に考え、実行したことで大きく成長ができました。具体的にはあいさつの徹底と、部活終わりの細かなフィードバックです。今思えば当たり前のことですが、当時はこのことに気づき、実行できた時にとても感動しました。このような物事の解決や最善の方法を考え、実行する経験は自らをとても成長させると思います。そのために、このインターンを通して、私は貴社の技術や社員の方々の考え方、そして仕事への向き合い方を最も近い距離で経験し、吸収することで仕事における自らの成長に繋げたいと考えております。私は近い将来、多くの人の生活を豊かにするサービスの開発に携わりたい。それが私の人生の充実に繋がると考えているからだ。私は学生の頃にニューラルネットワークを使い、手書き数字の分類や、マルバツゲームを作ったことがある。そして、自分の書いたプログラムが実際に動作した時に、とても感動し、自分の手で何かを作ることの楽しさを知った。また、3年間続けた塾講師のアルバイトでは、生徒の学力向上のために、毎回日報を書き、一人ひとりに適した指導方法を考えていた。これによりテストの点が上がった時は、生徒たち以上に喜んだ。誰かのために努力をし、それが実ったときの幸せは何にも変え難いものである。したがって、私はこの二つの経験から、誰かのためになるサービスを自らの手で作りたいと考えている。その経験は大きな自信や生きがいになるだろう。データはあるだけでなく使いこなせないと意味がないため、学んだことやこれから学ぶことを駆使して状況に応じたよりよいデータの使用方法を提案したいです。また、昔から想像力豊かで柔軟な発想が得意なため面白い新たなアイデアを出せると思います。周りを観察し状況をしっかり見極め、痒いところに手が届く人間になりたい。コミュニティケーション能力はもちろん、データの扱いにも秀でた存在になりたいと思っている。データはあるだけでなく使いこなせないと意味がないため、データサイエンティスト、学んだことやこれから学ぶことを駆使して状況に応じたよりよいデータの使用方法を提案したい。また、昔から想像力豊かで柔軟な発想が得意なため面白い新たなアイデアを出す自信がある。近い将来は多くの知識、技術をつけて人に頼られるエンジニアでいたい。また、今後働くにあたって自信となる経験が欲しいため、小さくても何かしらのプロジェクトを任され、それが成功するよう努力をする。データサイエンティスト。必要なことは挑戦できる機会から逃げないことである。人は嫌なことから簡単に逃げられるが、成長するためには未体験の領域にいくことも大切だろう。仮に失敗してもそれも良い経験となるからだ。そのような経験値がもっと得られれば、自信やスキルが身につき色々なことをクリアし、周りからの評価も上がると考えている。チーム、個人開発など当初はプログラミング未経験だったため、環境構築や基礎的な分析をおこなった。一年後にはチームで作品を開発しサークル内で発表した。私たちはニューラルネットワークを用いた丸バツゲームを作成した。AlphaZeroをもとにし、ランダム対戦したデータを学習させ良い手を打ち、さらにそのデータを使って学習させる、というシステムである。学習には三日間使い、人間と同等、全探索アルゴリズムとも五分五分といういい結果となった。長所は価値観を広げることに、重きを置いていることです。新たな発見や知識の収集に関心があり、他分野について精通している人間とも交流をとり、勉強面では少しでも気になったことは、すぐに調べています。しかし好奇心だけで即座に行動に移さず、慎重に物事を考えることも必要だと感じています。弱みは人前で自信を持って自分の意見を言うのに躊躇いがあることです。昔から流されやすい性格なため、思うことがあっても言わずにいることが多かったです。そんな自分を変えるため今では自分の頭で物事を考え積極的に意見を言うように努力しています。目標の立て方を大事にしている。行動する前に自分が興味を持っている分野に関連した論文を読み、何が行われていてその課題はどのような物なのか、そして自分はそれに対して何ができるかを明確にしてから目標を立てている。開発や研究でエラーが続いたり思うような結果が出ないような時に、ノートに手書きで問題点とその明確な解決方法を全て書くようにしていること。昔から考えていることをノートに書くと頭の整理ができて落ち着いて問題を対処できるため、今でもこの方法を使っている。必要なことは挑戦できる機会から逃げないことである。人は嫌なことから簡単に逃げられるが、成長するためには未体験の領域にいくことも大切だろう。仮に失敗してもそれも良い経験となるからだ。そのような経験値がもっと得られれば、自信やスキルが身につき色々なことをクリアし、周りからの評価も上がると考えている。私は強みは、問題解決能力である。私が塾講師のアルバイトをしていた頃、社員との会議で成績の上がらない問題が出た。そこで私は、講師たちが授業後に提出する電子日報に、内容に応じて報酬を与えるという制度を提案した。それにより講師たちはフィードバックをより正確に行うようになり、各生徒の得意不得意だけでなく、できなかったITコンサルやその間違い方まで細かく共有をし、とても指導がしやすくなった。生徒のやる気よりも、講師のやる気を上げた解決したのである。そして今では入塾困難な状況まで人気が出ている。この業務でも問題を様々な角度から見ることで、解決の糸口を掴みたい。私が貴社のインターンを志望する理由はコンサルタントという職業をもっと深く知りたいからです。昔から家族や友達、多くの人と助け合うことを大切にしていたため、自分の得意分野を使って人や企業の問題を解決し、支援をするコンサルタントにとても憧れがありました。3年間 ...
# Python 使う 引き分け 狙う オセロ AI 作成 する 探索 アルゴリズム モンテカルロ 木 探索 応用 する 論文 読む 分野 理解 深める 研究 おこなう 目標 達成 ため 既存 アルゴリズム 評価 方法 分岐 変更 加える 続ける 実験 たび フィードバック 得る 少し モデル 精度 上げる いく 研究 知識 技術 得る 一つ こと 本気 続ける 継続 する こと 大切 さ 知る こと できる 私 大学 最も 成果 残す 経験 卒業 研究 卒業 論文 執筆 内容 拮抗 する 試合 展開 行う オセロ AI 開発 モンテカルロ 木 探索 探索 アルゴリズム 応用 する 背景 ユーザー 実力 関係 ない 柔軟 対応 できる AI ある ゲーム 楽しむ レベルアップ 期待 できる システム 開発 できる 考える ため 多く 関連 する 論文 読む 分野 理解 深める 研究 行う こだわる 点 目標 達成 ため 既存 アルゴリズム 変更 加える 続ける 実験 たび フィードバック 得る 少し モデル 精度 上げる いく こと 結果 一定 レベル いくつ AI 相手 勝率 5 分 近い 値 収束 する こと できる プレゼン 時 スライド 見せる 方 こだわる グラフ ヒストグラム どう 使う わかる やすい 何 度 発表 練習 行う 考える 結果 何 伝える の 自分 しっかり 考える こと 必要 理解 できる 研究 知識 技術 得る 一つ こと 本気 続ける 継続 する こと 大切 さ 知る こと できる 私 学生 時代 最も 頑張る こと 塾 講師 アルバイト 生徒 たち 成績 あげる ため 試行 錯誤 する こと 当時 社員 会議 生徒 成績 上がる 問題 出る 私 問題 解決 する ため 講師 たち 提出 する 生徒 電子 日報 内容 応じる 報酬 与える 制度 提案 する IT IT データ たち フィードバック より 正確 行う よう なる 得意 不得意 苦労 する 問題 細かい 共有 する とても 指導 する やすい なる やる気 やる気 上げる こと 問題 解決 する の 友人 状況 人気 出る いる 業務 問題 様々 角度 見る こと 解決 糸口 掴む 長所 価値 観 広げる こと 重き 置く いる こと 新た 発見 知識 収集 関心 ある 分野 精通 する いる 人間 交流 とる 勉強 面 少し 気 なる こと すぐ 調べる いる 好奇 心 即座 行動 移す 慎重 物事 考える こと 必要 感じる いる 学生 時代 力 注ぐ こと 卒業 研究 得る られる 知識 技術 なる 自分 戦い 中 めげる 友人 支える 合う 最後 やる きる こと できる 経験 今後 社会 生活 活用 できる とても 価値 ある もの 思う いる 志望 する 理由 自分 スキル アップ 実際 責任 持つ 仕事 行う こと 得る られる 自己 成長 ため 経験 欲しい ため 私 学部 時代 情報 学 専攻 する おる 当時 授業 経験 活かす ニューラルネットワーク 用いる 自己 学習 する マルバツゲーム 作る こと ある 時 自分 書く プログラム 機械 自ら 学習 行う ゲーム 動作 する 時 強い 達成 感 覚える ため インターン 貴社 技術 社員 方々 考え方 仕事 向き合う 方 最も 近い 距離 経験 する 吸収 する こと 自ら 成長 繋げる 考える おる 志望 する 理由 自分 スキル アップ 実際 責任 持つ 仕事 行う こと 得る られる 自己 成長 ため 経験 欲しい ため 私 高校 時代 所属 する いる 水泳 部 部長 任す れる いる 時 今 責任 増える 状況 自分 何 する の 先生 一緒 考える 実行 する こと 大きい 成長 できる 具体 的 あいさつ 徹底 部活 終わる 細か フィードバック 今 思う 当たり前 こと 当時 こと 気づく 実行 できる 時 とても 感動 する よう 物事 解決 最善 方法 考える 実行 する 経験 自ら とても 成長 する せる 思う ため インターン 私 貴社 技術 社員 方々 考え方 仕事 向き合う 方 最も 近い 距離 経験 する 吸収 する こと 仕事 自ら 成長 繋げる 考える おる 私 近い 将来 多く 人 生活 豊か する サービス 開発 携わる それ 私 人生 充実 繋がる 考える いる 私 学生 頃 ニューラルネットワーク 使う 手書き 数字 分類 マルバツゲーム 作る こと ある 自分 書く プログラム 実際 動作 する 時 とても 感動 する 自分 手 何 作る こと 楽しい さ 知る 3 年間 続ける 塾 講師 アルバイト 生徒 学力 向上 ため 毎回 日報 書く 一人ひとり 適す 指導 方法 考える いる これ テスト 点 上がる 時 生徒 たち 以上 喜ぶ 誰か ため 努力 する それ 実る とき 幸せ 何 変える 難い もの 私 二つ 経験 誰 ため なる サービス 自ら 手 作る 考える いる 経験 自信 生きがい なる データ ある 使いこなせる 意味 ない ため 学ぶ こと これから 学ぶ こと 駆使 する 状況 応じる よい データ 使用 方法 提案 する 昔 想像 力 豊か 柔軟 発想 得意 ため 面白い 新た アイデア 出せる 思う 周り 観察 する 状況 しっかり 見極める 痒い ところ 手 届く 人間 なる コミュニティケーション 能力 もちろん データ 扱い 秀でる 存在 なる 思う いる データ ある 使いこなせる 意味 ない ため データ サイエンティスト 学ぶ こと これから 学ぶ こと 駆使 する 状況 応じる よい データ 使用 方法 提案 する 昔 想像 力 豊か 柔軟 発想 得意 ため 面白い 新た アイデア 出す 自信 ある 近い 将来 多く 知識 技術 つける 人 頼る れる エンジニア いる 今後 働く 自信 なる 経験 欲しい ため 小さい 何かしら プロジェクト 任す れる それ 成功 する よう 努力 する データ サイエンティスト 必要 こと 挑戦 できる 機会 逃げる こと 人 嫌 こと 簡単 逃げる られる 成長 する ため 体験 領域 いく こと 大切 仮に 失敗 する それ 良い 経験 なる よう 経験 値 もっと 得る られる 自信 スキル 身 色々 こと クリア する 周り 評価 上がる 考える いる チーム 個人 開発 当初 プログラミング 経験 ため 環境 構築 基礎 的 分析 おこなう 一 年 後 チーム 作品 開発 する サークル 内 発表 する 私 たち ニューラルネットワーク 用いる 丸 バツ ゲーム 作成 する AlphaZero もと する ランダム 対戦 する データ 学習 する せる 良い 手 打つ さらに データ 使う 学習 する せる システム 学習 三 日間 使う 人間 同等 探索 アルゴリズム 五分五分 いい 結果 なる 長所 価値 観 広げる こと 重き 置く いる こと 新た 発見 知識 収集 関心 ある 分野 精通 する いる 人間 交流 とる 勉強 面 少し 気 なる こと すぐ 調べる いる 好奇 心 即座 行動 移す 慎重 物事 考える こと 必要 感じる いる 弱み 人前 自信 持つ 自分 意見 言う の 躊躇う ある こと 昔 流す れる やすい 性格 ため 思う こと ある 言う いる こと 多い 自分 変える ため 今 自分 頭 物事 考える 積極 的 意見 言う よう 努力 する いる 目標 立てる 方 大事 する いる 行動 する 前 自分 興味 持つ いる 分野 関連 する 論文 読む 何 行う れる いる 課題 よう 物 の 自分 それ 何 できる 明確 する 目標 立てる いる 開発 研究 エラー 続く 思う よう 結果 出る よう 時 ノート 手書き 問題 点 明確 解決 方法 全て 書く よう する いる こと 昔 考える いる こと ノート 書く 頭 整理 できる 落ち着く 問題 対処 できる ため 今 方法 使う いる 必要 こと 挑戦 できる 機会 逃げる こと 人 嫌 こと 簡単 逃げる られる 成長 する ため 体験 領域 いく こと 大切 仮に 失敗 する それ 良い 経験 なる よう 経験 値 もっと 得る られる 自信 スキル 身 色々 こと クリア する 周り 評価 上がる 考える いる 私 強み 問題 解決 能力 私 塾 講師 アルバイト する いる 頃 社員 会議 成績 上がる 問題 出る 私 講師 たち 授業 後 提出 する 電子 日報 内容 応じる 報酬 与える 制度 提案 する それ 講師 たち フィードバック より 正確 行う よう なる 生徒 得意 不得意 できる IT コン サル 間違い 方 細かい 共有 する とても 指導 する やすい なる 生徒 やる気 講師 やる気 上げる 解決 する の 今 入塾 困難 状況 人気 出る いる 業務 問題 様々 角度 見る こと 解決 糸口 掴む 私 貴社 インターン 志望 する 理由 コンサルタント 職業 もっと 深い 知る 昔 家族 友達 多く 人 助け合う こと 大切 する いる ため 自分 得意 分野 使う 人 企業 問題 解決 する 支援 する コンサルタント とても 憧れる ある 3 年間 続ける 塾 講師 アルバイト 積極 的 生徒 たち 学力 ...

# %%
from collections import Counter
from wordcloud import WordCloud
from typing import List
import datetime as dt

# %%
def make_wordcloud_image(words:List) -> List:
    # フォントを指定する
    WORDCLOUD_FONT_PATH = "/Library/Fonts/Arial Unicode.ttf"

    # 画像のサイズを指定
    WORDCLOUD_WIDTH = 600
    WORDCLOUD_HEIGHT = 600

    # 文字の色を指定する
    WORDCLOUD_BG_COLOR = 'white'
    # 出力先とファイル名を日付で指定
    WORDCLOUD_OUTPUT_FILE = './' + dt.datetime.now().strftime('%Y%m%d') + '.png'

    # 頻出ワードが何かを調べる
    word_counter = Counter(words)
    wordcloud = WordCloud(
        font_path = WORDCLOUD_FONT_PATH,
        width = WORDCLOUD_WIDTH,
        height = WORDCLOUD_HEIGHT,
        background_color = WORDCLOUD_BG_COLOR).generate_from_frequencies(word_counter)
    wordcloud.to_file(WORDCLOUD_OUTPUT_FILE)

# %%
make_wordcloud_image(sent)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-19-e7299a38868a> in <cell line: 1>()
# ----> 1 make_wordcloud_image(sent)
#
# <ipython-input-18-86126819ac13> in make_wordcloud_image(words)
#      18         width = WORDCLOUD_WIDTH,
#      19         height = WORDCLOUD_HEIGHT,
# ---> 20         background_color = WORDCLOUD_BG_COLOR).generate_from_frequencies(word_counter)
#      21     wordcloud.to_file(WORDCLOUD_OUTPUT_FILE)
#
# /usr/local/lib/python3.10/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     451                 font_size = self.height
#     452             else:
# --> 453                 self.generate_from_frequencies(dict(frequencies[:2]),
#     454                                                max_font_size=self.height)
#     455                 # find font sizes
#
# /usr/local/lib/python3.10/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     501             while True:
#     502                 # try to find a position
# --> 503                 font = ImageFont.truetype(self.font_path, font_size)
#     504                 # transpose font optionally
#     505                 transposed_font = ImageFont.TransposedFont(
#
# /usr/local/lib/python3.10/dist-packages/PIL/ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     853
#     854     try:
# --> 855         return freetype(font)
#     856     except OSError:
#     857         if not isPath(font):
#
# /usr/local/lib/python3.10/dist-packages/PIL/ImageFont.py in freetype(font)
#     850
#     851     def freetype(font):
# --> 852         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     853
#     854     try:
#
# /usr/local/lib/python3.10/dist-packages/PIL/ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     209                         load_from_bytes(f)
#     210                     return
# --> 211             self.font = core.getfont(
#     212                 font, size, index, encoding, layout_engine=layout_engine
#     213             )
#
# OSError: cannot open resource

# %%
# !apt-get -y install fonts-ipafont-gothic
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-ipafont-mincho
# The following NEW packages will be installed:
#   fonts-ipafont-gothic fonts-ipafont-mincho
# 0 upgraded, 2 newly installed, 0 to remove and 13 not upgraded.
# Need to get 8,251 kB of archives.
# After this operation, 28.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-ipafont-gothic all 00303-18ubuntu1 [3,526 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-ipafont-mincho all 00303-18ubuntu1 [4,725 kB]
# Fetched 8,251 kB in 0s (16.9 MB/s)
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 123749 files and directories currently installed.)
# Preparing to unpack .../fonts-ipafont-gothic_00303-18ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-18ubuntu1) ...
# Selecting previously unselected package fonts-ipafont-mincho.
# Preparing to unpack .../fonts-ipafont-mincho_00303-18ubuntu1_all.deb ...
# Unpacking fonts-ipafont-mincho (00303-18ubuntu1) ...
# Setting up fonts-ipafont-mincho (00303-18ubuntu1) ...
# update-alternatives: using /usr/share/fonts/opentype/ipafont-mincho/ipam.ttf to provide /usr/share/fonts/truetype/fonts-japanese-mincho.ttf (fonts-japanese-mincho.ttf) in auto mode
# Setting up fonts-ipafont-gothic (00303-18ubuntu1) ...
# update-alternatives: using /usr/share/fonts/opentype/ipafont-gothic/ipag.ttf to provide /usr/share/fonts/truetype/fonts-japanese-gothic.ttf (fonts-japanese-gothic.ttf) in auto mode
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
